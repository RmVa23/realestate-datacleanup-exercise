# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de fotocasa, el cual es uno de los sitios mas populares de bienes raíces en España. Por favor no hagas estos (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa mas cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!
#
# Let's start with precisely that question... Good luck!

# %%
print(123)
# Out:
# 123

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
data = pd.read_csv('real_estate.csv', sep=';')
data
# Out:
#       Unnamed: 0  id_realEstates  isNew  \
# 0              1       153771986  False
# 1              2       153867863  False
# 2              3       153430440  False
# 3              4       152776331  False
# 4              5       153180188  False
# ...          ...             ...    ...
# 5264        5265       153989173  False
# 5265        5266       149476258  False
# 5266        5267       153503712  False
# 5267        5268       153499139  False
# 5268        5269       153019499  False
#
#                                         realEstate_name  phone_realEstate  \
# 0                               ferrari 57 inmobiliaria       912177526.0
# 1                     tecnocasa fuenlabrada ferrocarril       916358736.0
# 2                                    look find boadilla       916350408.0
# 3                     tecnocasa fuenlabrada ferrocarril       916358736.0
# 4                               ferrari 57 inmobiliaria       912177526.0
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa mas cara en el todo el dataset? (★☆☆)
#
# Imprime la direccion y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
direcc = data[data['price'] == data.price.max()]['address']
precio = data[data['price'] == data.price.max()]['price']

print(f'El inmueble que se encuentra en {direcc.values[0]} es la más cara, con un precio de {precio.values[0]}')
# Out:
# El inmueble que se encuentra en Calle Amorebieta,  Madrid Capital es la más cara, con un precio de 7800000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa mas barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
direcc = data[data['price'] == data.price.min()]['address']
precio = data[data['price'] == data.price.min()]['price']

print(f'El inmueble que se encuentra en {direcc.values[0]} es la más barata, con un precio de {precio.values[0]}')
# Out:
# El inmueble que se encuentra en Parla es la más barata, con un precio de 0

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa mas grande y la mas pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el area de las casas seleccionadas. Por ejemplo:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
dirmax = data[data['surface'] == data.surface.max()]['address']
surmax = data[data['surface'] == data.surface.max()]['surface']

dirmin = data[data['surface'] == data.surface.min()]['address']
surmin = data[data['surface'] == data.surface.min()]['surface']

print(f'The bigger house is located on {dirmax.values[0]} and its surface is {surmax.values[0]} meters.')
print(f'The smaller house is located on {dirmin.values[0]} and its surface is {surmin.values[0]} meters.')
# Out:
# The bigger house is located on Calle Canario 2  Los Ranchos, Galapagar and its surface is 5083.0 meters.
# The smaller house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters.

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
poblaciones = list(data.level5.unique())
print(poblaciones)
print(len(poblaciones))

zonas = list(set(data.level5))
print(zonas)
print(len(zonas))
# Out:
# ['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte', 'Las Rozas de Madrid', ' Madrid Capital', 'Villaviciosa de Odón', 'Pinto', 'Valdemoro', 'Navalcarnero', 'Pozuelo de Alarcón', 'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes', 'Rivas-vaciamadrid', 'Alpedrete', 'Móstoles', 'San Fernando de Henares', 'Coslada', 'Becerril de la Sierra', 'Alcalá de Henares', 'Chinchón', 'Parla', 'Alcorcón', 'El Escorial', 'Leganés', 'Pedrezuela', 'Majadahonda', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Torrelodones', 'Moralzarzal', 'Mejorada del Campo', 'Aranjuez', 'Corpa', 'Getafe', 'Velilla de San Antonio', 'Sevilla la Nueva', 'San Martín de la Vega', 'Villalbilla', 'Collado Villalba', 'Alcobendas', 'El Molar (Madrid)', 'Moraleja de Enmedio', 'Algete', 'Campo Real', 'Torrejón de la Calzada', 'Colmenar Viejo', 'Valdemorillo', 'Fuente El Saz de Jarama', 'Tres Cantos', 'Arroyomolinos (Madrid)', 'Griñón', 'Paracuellos de Jarama', 'Guadarrama', 'Titulcia', 'Galapagar', '
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El data set contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`true` o `fase`) seguido de la fila/columna que contiene el NAs.

# %%
por_columns = data.isnull().any()
print(por_columns)
por_conjunto = data.isnull().any().any()
print(por_conjunto)
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel           True
# countryId            True
# level1Id             True
# level2Id             True
# level3Id             True
# level4Id             True
# level5Id             True
# level6Id             True
# level7Id             True
# level8Id             True
# accuracy             True
# latitude             True
# longitude            True
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del data set, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
print("DataSet Original:")
print(data['address'].head())

data1 = data.dropna(axis=1)
print("DataSet sin columnas que contienen al menos un valos nulo:")
print(data1['address'].head())

data2 = data.dropna()
print("DataSet sin filas que contienen al menos un valor nulo:")
print(data2['address'].head())

data3 = data.dropna(axis=1, how = 'all')
print("DataSet solo sin las columnas que tienen todos los valores nulos:")
print(data3['address'].head())
# Out:
# DataSet Original:
# 0    Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                     Calle Polvoranca, 6, Fuenlabrada
# 2            Calle Reyes Católicos, Boadilla del Monte
# 3                       Barrio San Andres, Fuenlabrada
# 4                                      Arganda del Rey
# Name: address, dtype: object
# DataSet sin columnas que contienen al menos un valos nulo:
# 0    Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                     Calle Polvoranca, 6, Fuenlabrada
# 2            Calle Reyes Católicos, Boadilla del Monte
# 3                       Barrio San Andres, Fuenlabrada
# 4                                      Arganda del Rey
# Name: address, dtype: object
# DataSet sin filas que contienen al menos un valor nulo:
# Series([], Name: address, dtype: object)
# DataSet solo sin las columnas que tienen todos los valores nulos:
# 0    Calle Presidente Felipe Gonzalez, Arganda del Rey
# 1                     Calle Polvoranca, 6, Fuenlabrada
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido

# %%
data_arroyomolinos = data[data['level5'] == 'Arroyomolinos (Madrid)']
precio_medio = data_arroyomolinos['price'].mean()
print(precio_medio)
# Out:
# 291930.1641791045

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
precio = data_arroyomolinos.filter(['price'])

import matplotlib.pyplot as plt
plt.figure(figsize = (10, 5))
plt.hist(precio, bins=50, alpha=0.8)
plt.title("Distribución de precios en Arroyomolinos (Madrid)")
plt.xlabel("precio")
plt.ylabel("cantidad")
plt.show()

print("Zona de poder adquisitivo medio-alto")
# Out:
# Zona de poder adquisitivo medio-alto

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en este celda y elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿ Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedio y escribe una conclusion acerca de ellos

# %%
val1 = data[data['level5'] == 'Valdemorillo']
pm_valdemorillo = val1['price'].mean()
gal1 = data[data['level5'] == 'Galapagar']
pm_galapagar = gal1['price'].mean()
if pm_valdemorillo < pm_galapagar:
    print("La zona de Galapagar es más valorada que la de Valdemorillo")
elif pm_valdemorillo > pm_galapagar:
    print("La zona de Valdemorillo es más valorada que la de Galapagar")
else:
    print("Las zonas de Valdemorillo y Galapagar tienen el mismo precio promedio")
# Out:
# La zona de Galapagar es más valorada que la de Valdemorillo

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (price/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio y escribe una conclusion acerca de ellos.
#
# Pista: Crea una nueva columna llamada `pps` (price per square) y luego analiza los valore.s

# %%
data['pps'] = data['price'] / data['surface']
pps_val = data[data['level5'] == 'Valdemorillo']['pps'].mean()
pps_gal = data[data['level5'] == 'Galapagar']['pps'].mean()
print(pps_val)
print(pps_gal)

print("El precio medio por metro cuadrado en Valdemorillo es más económico que el de la zona de Galapagar.")
# Out:
# 1334.3811880367846
# 1451.9586575755295
# El precio medio por metro cuadrado en Valdemorillo es más económico que el de la zona de Galapagar.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusion al respecto.

# %%
data2 = data.loc[:, ['price', 'surface']]
data4 = data2.dropna()

import matplotlib.pyplot as plt
sp = list(data4['surface'])
pr= list(data4['price'])

plt.figure(figsize = (10, 5))
plt.scatter(sp, pr)
plt.title("Precio y superficie")
plt.xlabel('superficie')
plt.ylabel('precio')
plt.show()

print("Casi todas las casas no superan los 500m2, y la dispersión de precios de éstas indica que son los inmuebles más comunes listados, la práctica totalidad.")
print("Sin embargo encontramos dos propiedades que superan enormemente la superficie común de los inmuebles, pero el precio es muy bajo, lo que podría indicar una muy baja demanda de propiedades de tanta superficie.")


data4.drop(data4.loc[data4["surface"]>1000].index, inplace=True)

s = list(data4['surface'])
p= list(data4['price'])

plt.figure(figsize = (10, 5))
plt.scatter(s, p)
plt.title("Precio y superficie de los inmuebles menores de 1000m2")
plt.xlabel('superficie')
plt.ylabel('precio')
plt.show()
# Out:
# Casi todas las casas no superan los 500m2, y la dispersión de precios de éstas indica que son los inmuebles más comunes listados, la práctica totalidad.
# Sin embargo encontramos dos propiedades que superan enormemente la superficie común de los inmuebles, pero el precio es muy bajo, lo que podría indicar una muy baja demanda de propiedades de tanta superficie.
# <ipython-input-19-a01c9132d9f0>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4.drop(data4.loc[data4["surface"]>1000].index, inplace=True)

# %% [markdown]
# **TODO: Markdown**. Escribe aquí, haz doble click en este celda y elimina este contenido y reemplázalo por el texto que quires escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
agencias = list(data.realEstate_name.unique())
print('El numero de agencias en el dataset es: ' + str(len(agencias)))
# Out:
# El numero de agencias en el dataset es: 968

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
rep = data['level5'].value_counts()
maxi = rep.max(skipna = True)
print(f"La población con más inmuebles es Madrid Capital con {maxi} en total.")
# Out:
# La población con más inmuebles es Madrid Capital con 2297 en total.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Has un subconjunto del Dataframe original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Pista: Filtra el Dataframe original usando la columna `level5` y la función `isin`

# %%
new_data = data[data['level5'].isin(['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón'])]
#print(new_data1.head())
print(new_data.loc[:, ['level5', 'price', 'surface']].head(10))
# Out:
#           level5   price  surface
# 1    Fuenlabrada   89000      NaN
# 3    Fuenlabrada   89000     86.0
# 85      Alcorcón  107000     50.0
# 94       Leganés  320000    120.0
# 109     Alcorcón  425000    142.0
# 161  Fuenlabrada  239500    123.0
# 169       Getafe  290000    195.0
# 189      Leganés   60000     60.0
# 193      Leganés  140000     70.0
# 214  Fuenlabrada  184000    175.0

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barra de la media de los precios y explica lo que observas (debes usar el subconjunto obtenido de la pregunta 14) (★★★)
#
# Imprima un gráfico de barra de la media de precios y escriba en la celda Markdown un breve análisis del sector.

# %%
plt.figure(figsize = (10, 5))
media = new_data.groupby('level5')['price'].mean()
plt.bar(media.index, media.values)
plt.title('Gráficos precios promedio')
plt.xlabel("Cantidad e inmuebles")
plt.ylabel("Precio medio")
plt.show()

print('Getafe es la zona más cara Y Fuenlabrada es la más barata, Alcorcón y Leganés no tienen mucha diferencia entre ellas')
# Out:
# Getafe es la zona más cara Y Fuenlabrada es la más barata, Alcorcón y Leganés no tienen mucha diferencia entre ellas

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en esta celda, elimina este contenido y coloca en su lugar el texto que quieres escribir. Luego, ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza dela muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Imprime ambos valores por  cada variable.

# %%
k = (new_data.groupby(lambda _: "").agg(
   Precio = ('price', 'mean'),
   Habitaciones = ('rooms', 'mean'),
   Superficie = ('surface', 'mean'),
   Baños = ('bathrooms', 'mean'))
)

v = (new_data.groupby(lambda _: "").agg(
    Precio = ('price', 'var'),
    Habitaciones = ('rooms', 'var'),
    Superficie = ('surface', 'var'),
    Baños = ('bathrooms', 'var')
))

final = pd.concat([k, v], axis=0)
final.index = ['Media', 'Varianza']
print(final)
# Out:
#                 Precio  Habitaciones   Superficie     Baños
# Media     2.361776e+05      3.039088   114.099206  1.682119
# Varianza  1.809880e+10      0.658598  5314.464222  0.543134

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
dmax = new_data.groupby('level5')['price'].idxmax()
pmax = new_data.loc[dmax, ['level5', 'address', 'price']]
print(pmax)
# Out:
#            level5                         address    price
# 1903     Alcorcón  Calle Copenhague, 60, Alcorcón   602800
# 4753  Fuenlabrada                     Fuenlabrada   452500
# 2881       Getafe                          Getafe  1050000
# 2565      Leganés                         Leganés   487000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
plt.figure(figsize=(10, 5))

pob = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

for i in pob:
    poblacion = new_data[new_data['level5'] == i]
    precio = poblacion['price']
    norm = (precio - precio.mean()) / precio.std()

    plt.hist(norm, bins=30, alpha=0.3,label = i )

plt.title("Histograma normalización de precios")
plt.xlabel("Precios normalizados")
plt.ylabel("Poblaciones")
plt.legend(loc="upper right")
plt.show()

print("Los valores de cada columna ahora están normalizados de modo que la media de los valores de cada columna sea 0 y la desviación estándar de los valores de cada columna sea 1")
print("La gráfica muestra que Getafe es la más cara y con mayor dispersiñon de precios, al punto que modifica la media, ya que las otras tres zonas restantes acumulan mñas por debajo de la media.")
# Out:
# Los valores de cada columna ahora están normalizados de modo que la media de los valores de cada columna sea 0 y la desviación estándar de los valores de cada columna sea 1
# La gráfica muestra que Getafe es la más cara y con mayor dispersiñon de precios, al punto que modifica la media, ya que las otras tres zonas restantes acumulan mñas por debajo de la media.

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
comparation = new_data.loc[:, ['surface', 'price']]
comparation['pps'] = comparation['price'] / comparation['surface']


media_g = new_data[new_data['level5'] == 'Getafe']['pps'].mean()
media_a = new_data[new_data['level5'] == 'Alcorcón']['pps'].mean()

var_g = new_data[new_data['level5'] == 'Getafe']['pps'].var(ddof=0)
var_a = new_data[new_data['level5'] == 'Alcorcón']['pps'].var(ddof=0)

print(f"El precio medio por metro cuadrado es de {media_g} en Getafe, y de {media_a} en Alcorcón")

if media_g < media_a:
    print('En promedio, Getafe es una zona más económica que Alcorcón')
elif media_g > media_a:
    print('Getafe es más cara que Alcorcón')
else:
    print('Getafe y Alcorcón tienen el mismo precio por m2')

if var_a < var_g:
    print('Los precios por m2 entre inmuebles son más dispares en Getafe')
elif var_a > var_g:
    print('Los precios por m2 entre inmuebles son más dispares en Alcorcón')
else:
    print('Hay la misma disparidad de precios entre inmuebles en ambas zonas')
# Out:
# El precio medio por metro cuadrado es de 2043.7716553272771 en Getafe, y de 2242.306976322737 en Alcorcón
# En promedio, Getafe es una zona más económica que Alcorcón
# Los precios por m2 entre inmuebles son más dispares en Getafe

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
Fuenlabrada = new_data[new_data['level5'].isin(fuenla)]
xf = Fuenlabrada['price']
yf = Fuenlabrada['surface']

Leganés = new_data[new_data['level5'].isin(leg)]
xl = Leganés['price']
yl = Leganés['surface']

Getafe = new_data[new_data['level5'].isin(gtf)]
xg = Getafe['price']
yg = Getafe['surface']

Alcorcón = new_data[new_data['level5'].isin(alco)]
xa = Alcorcón['price']
ya = Alcorcón['surface']

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 10))

ax1.scatter(xf, yf)
ax1.set_xlabel('precio')
ax1.set_ylabel('superficie')

ax2.scatter(xl, yl)
ax2.set_xlabel('precio')
ax2.set_ylabel('superficie')


ax3.scatter(xg, yg)
ax3.set_xlabel('precio')
ax3.set_ylabel('superficie')


ax4.scatter(xa, ya)
ax4.set_xlabel('precio')
ax4.set_ylabel('superficie')

plt.show()


plt.figure(figsize = (10, 5))

plt.scatter(xf, yf, color='red', label = 'Fuenlabrada')
plt.scatter(xl, yl, color='blue', label = 'Leganés')
plt.scatter(xg, yg, color='yellow', label = 'Getafe')
plt.scatter(xa, ya, color='orange', label = 'Alcorcón')

plt.title('Gráfico')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d887adeabc9f> in <cell line: 1>()
# ----> 1 Fuenlabrada = new_data[new_data['level5'].isin(fuenla)]
#       2 xf = Fuenlabrada['price']
#       3 yf = Fuenlabrada['surface']
#       4
#       5 Leganés = new_data[new_data['level5'].isin(leg)]
#
# NameError: name 'fuenla' is not defined

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón ur de Madrid por color d cada población (debes usar el subconjunto obtenido en la pregunta 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar u código simple que transforme las columnas de coordenadas en un diccionario de python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud et -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/xyzservices/lib.py in __getattr__(self, key)
#      43         try:
# ---> 44             return self.__getitem__(key)
#      45         except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fcb3cd5e7017> in <cell line: 5>()
#       4 # Latitud, longitud
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# /usr/local/lib/python3.10/dist-packages/xyzservices/lib.py in __getattr__(self, key)
#      44             return self.__getitem__(key)
#      45         except KeyError as err:
# ---> 46             raise AttributeError(key) from err
# ...

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

from ipyleaflet import Map, basemaps, Marker

m = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[60, -2.2], zoom = 2, min_zoom = 1, max_zoom = 20)

mapa_data = new_data.loc[:, ['level5', 'latitude', 'longitude']]
dm = mapa_data.dropna()
print(dm)

dfn = dm.convert_dtypes()
print(dm.info())

# Add markers for each property with different colors based on population

for index, row in mapa_data.iterrows():
    if (row['level5'] in mapa_data) == 'Fuenlabrada':
        markerF = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(markerF)
    elif (row['level5'] in mapa_data) == 'Alcorcón':
        markerA = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(markerA)
    elif (row['level5'] in mapa_data) == 'Getafe':
        markerG = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(markerG)
    elif (row['level5'] in mapa_data) == 'Leganés':
        icon = AwesomeIcon(name="home", marker_color=icon_colors[row['level5']], icon_color="orange")
        marker = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(marker)



# Save the map to an HTML file
#m.save('south_belt_map.html')
# Out:
#            level5          latitude          longitude
# 1     Fuenlabrada          40,28674           -3,79351
# 3     Fuenlabrada  40,2853785786438  -3,79508142135624
# 85       Alcorcón          40,35059           -3,82693
# 94        Leganés          40,31933           -3,77574
# 109      Alcorcón        40,3313411         -3,8313868
# ...           ...               ...                ...
# 5191      Leganés          40,35679           -3,77956
# 5252       Getafe          40,31376            -3,7209
# 5253     Alcorcón          40,35022           -3,82184
# 5254      Leganés          40,32739           -3,76408
# 5255      Leganés           40,3291           -3,75182
#
# [307 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 1 to 5255
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level5     307 non-null    object
#  1   latitude   307 non-null    object
# ...

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

from ipyleaflet import Map, basemaps, Marker

m = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[60, -2.2], zoom = 2, min_zoom = 1, max_zoom = 20)

mapa_data = new_data.loc[:, ['level5', 'latitude', 'longitude']]
dm = mapa_data.dropna()
print(dm)

dfn = dm.convert_dtypes()
print(dm.info())

# Add markers for each property with different colors based on population

for index, row in mapa_data.iterrows():
    if (row['level5'] in mapa_data) == 'Fuenlabrada':
        markerF = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(markerF)
    elif (row['level5'] in mapa_data) == 'Alcorcón':
        markerA = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(markerA)
    elif (row['level5'] in mapa_data) == 'Getafe':
        markerG = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(markerG)
    elif (row['level5'] in mapa_data) == 'Leganés':
        icon = AwesomeIcon(name="home", marker_color=icon_colors[row['level5']], icon_color="orange")
        marker = Marker(location=(convert_to_float(row['latitude']), convert_to_float(row['longitude'])))
        m.add(marker)



# Save the map to an HTML file
#m.save('south_belt_map.html')
# Out:
#            level5          latitude          longitude
# 1     Fuenlabrada          40,28674           -3,79351
# 3     Fuenlabrada  40,2853785786438  -3,79508142135624
# 85       Alcorcón          40,35059           -3,82693
# 94        Leganés          40,31933           -3,77574
# 109      Alcorcón        40,3313411         -3,8313868
# ...           ...               ...                ...
# 5191      Leganés          40,35679           -3,77956
# 5252       Getafe          40,31376            -3,7209
# 5253     Alcorcón          40,35022           -3,82184
# 5254      Leganés          40,32739           -3,76408
# 5255      Leganés           40,3291           -3,75182
#
# [307 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307 entries, 1 to 5255
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level5     307 non-null    object
#  1   latitude   307 non-null    object
# ...

# %%
# Convertimos las coordenadas a float
dm['latitude'] = dm['latitude'].apply(lambda x:float(x.replace(',','.')))
dm['longitude'] = dm['longitude'].apply(lambda x:float(x.replace(',','.')))

# %%
from ipyleaflet import Map, Marker, basemaps, AwesomeIcon

# Creamos el mapa
m = Map(basemap=basemaps.OpenStreetMap.Mapnik, center=[60, -2.2], zoom = 2, min_zoom = 1, max_zoom = 20)

# Diccionario de colores
d_color = {'Fuenlabrada':'blue','Alcorcón':'red','Getafe':'green'}

# Iteramos
for index, row in dm.iterrows():
  # Accedemos a la ciudad sobre la que iteramos
  ciudad = row['level5']
  # Definimos la lista de ciudades de interés
  ls_city = ['Fuenlabrada','Alcorcón','Getafe']
  # Si la ciudad es una ciudad de interés
  if ciudad in ls_city:
    icon = AwesomeIcon(name="home", marker_color="red", icon_color=d_color.get(ciudad))
    marker = Marker(icon=icon, location=(row['latitude'], row['longitude']))
    m.add_layer(marker)

# %%
m
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
import folium

# Create a map centered on a location (e.g., Madrid)
m = folium.Map(location=[40.416775, -3.703790], zoom_start=10)

# Define colors for each population
population_colors = {
    "Fuenlabrada": 'blue',
    "Leganés": 'green',
    "Getafe": 'red',
    "Alcorcón": 'purple'
}



# Add markers for each property with different colors based on population
for index, row in dm.iterrows():
    if row['level5'] in population_colors.keys():
        latitude = row['latitude']
        longitude = row['longitude']

        folium.CircleMarker(
            location=[latitude, longitude],
            radius=5,
            color=population_colors[row['level5']],
            fill=True,
            fill_color=population_colors[row['level5']],
            fill_opacity=0.6,
            popup=row['level5']
        ).add_to(m)

# Save the map to an HTML file
m.save('south_belt_map.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
l1 = [1,2,3]
l2 = [4,5,6]
# l3 = [5,7,9]

# %%
list(map(sum,zip(l1,l2)))
# Out:
# [5, 7, 9]
